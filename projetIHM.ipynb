# %%
# importing google drive
# from google.colab import drive
# drive.mount('/content/drive')

  # This Python 3 environment comes with many helpful analytics libraries installed

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import os

#required libraries
import cv2
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input
from keras.utils import to_categorical
from keras.models import Model, Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D,Activation
from tensorflow.keras.optimizers.legacy import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121
from keras.models import Sequential
import PIL
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 27
#      25 from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D,Activation
#      26 from tensorflow.keras.optimizers.legacy import Adam
# ---> 27 from keras.preprocessing.image import ImageDataGenerator
#      28 from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
#      29 from keras.applications import DenseNet121
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (C:\Users\fatima ezzahra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\preprocessing\image\__init__.py)

# %%
pip install distutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement distutils (from versions: none)
# ERROR: No matching distribution found for distutils

# %%
classes_types=['M', 'B']
data_path = "/content/drive/MyDrive/Breast Cancer Dataset"
data_dir = '/content/drive/MyDrive/Breast Cancer Dataset'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(classes_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'Class ID','Class Type'])
train.head()
# Out:
#           File  Class ID Class Type
# 0  M/2-117.jpg         0          M
# 1  M/2-057.jpg         0          M
# 2  M/2-008.jpg         0          M
# 3  M/2-289.jpg         0          M
# 4  M/2-058.jpg         0          M

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#           File  Class ID Class Type
# 0  M/2-270.jpg         0          M
# 1  B/1-248.jpg         1          B
# 2  B/1-229.jpg         1          B
# 3  M/2-267.jpg         0          M
# 4  M/2-141.jpg         0          M

# %%
plt.hist(train['Class ID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 600it [09:31,  1.05it/s]
# Train Shape: (600, 224, 224, 3)

# %%
Y_train = train['Class ID'].values
Y_train = to_categorical(Y_train, num_classes=3)

# %%
BATCH_SIZE = 64
# Split the train and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
from keras.layers import Dense, Flatten
from keras.models import Sequential

def create_ResNet50_CNN(input_shape=(224, 224, 3), num_classes=3):
    # Load the ResNet50 model pre-trained on ImageNet
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the base model's layers so that they're not trainable
    for layer in base_model.layers:
        layer.trainable = False

    # Create a new model using the ResNet50 base and additional layers
    model = Sequential()
    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    # Compile the model with categorical cross-entropy loss and Adam optimizer
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# Create a ResNet50-based CNN with default input shape (224x224x3) and 3 output classes
model = create_ResNet50_CNN()

# Train the model on your data for 50 epochs
hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=50)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step
# Epoch 1/50
# 15/15 [==============================] - 154s 10s/step - loss: 5.7073 - accuracy: 0.5042 - val_loss: 2.8630 - val_accuracy: 0.6083
# Epoch 2/50
# 15/15 [==============================] - 135s 9s/step - loss: 1.7179 - accuracy: 0.6458 - val_loss: 0.5888 - val_accuracy: 0.8417
# Epoch 3/50
# 15/15 [==============================] - 132s 9s/step - loss: 1.3116 - accuracy: 0.7271 - val_loss: 1.0400 - val_accuracy: 0.5583
# Epoch 4/50
# 15/15 [==============================] - 115s 8s/step - loss: 0.7059 - accuracy: 0.8208 - val_loss: 0.3825 - val_accuracy: 0.8750
# Epoch 5/50
# 15/15 [==============================] - 118s 8s/step - loss: 0.5237 - accuracy: 0.8354 - val_loss: 0.3012 - val_accuracy: 0.8750
# Epoch 6/50
# 15/15 [==============================] - 132s 9s/step - loss: 0.4525 - accuracy: 0.8375 - val_loss: 0.2801 - val_accuracy: 0.8750
# Epoch 7/50
# 15/15 [==============================] - 136s 9s/step - loss: 0.6111 - accuracy: 0.7542 - val_loss: 0.7715 - val_accuracy: 0.7167
# Epoch 8/50
# 15/15 [==============================] - 133s 9s/step - loss: 0.4365 - accuracy: 0.8438 - val_loss: 0.6200 - val_accuracy: 0.7417
# Epoch 9/50
# 15/15 [==============================] - 115s 8s/step - loss: 1.0134 - accuracy: 0.6854 - val_loss: 0.9956 - val_accuracy: 0.6000
# Epoch 10/50
# 15/15 [==============================] - 133s 9s/step - loss: 1.2276 - accuracy: 0.7042 - val_loss: 0.6684 - val_accuracy: 0.7083
# Epoch 11/50
# 15/15 [==============================] - 115s 8s/step - loss: 1.8307 - accuracy: 0.6708 - val_loss: 4.3795 - val_accuracy: 0.6083
# Epoch 12/50
# 15/15 [==============================] - 113s 8s/step - loss: 1.8188 - accuracy: 0.7125 - val_loss: 0.4316 - val_accuracy: 0.8917
# Epoch 13/50
# 15/15 [==============================] - 135s 9s/step - loss: 0.5689 - accuracy: 0.8667 - val_loss: 0.4358 - val_accuracy: 0.8833
# Epoch 14/50
# 15/15 [==============================] - 115s 8s/step - loss: 0.5825 - accuracy: 0.8333 - val_loss: 0.4887 - val_accuracy: 0.8000
# Epoch 15/50
# 15/15 [==============================] - 135s 9s/step - loss: 0.3978 - accuracy: 0.8708 - val_loss: 0.2898 - val_accuracy: 0.8917
# Epoch 16/50
# 15/15 [==============================] - 112s 8s/step - loss: 0.3341 - accuracy: 0.8604 - val_loss: 0.3332 - val_accuracy: 0.8667
# Epoch 17/50
# 15/15 [==============================] - 114s 8s/step - loss: 0.4811 - accuracy: 0.8354 - val_loss: 0.3312 - val_accuracy: 0.8750
# Epoch 18/50
# 15/15 [==============================] - 112s 8s/step - loss: 0.3886 - accuracy: 0.8542 - val_loss: 0.7620 - val_accuracy: 0.7500
# Epoch 19/50
# 15/15 [==============================] - 114s 8s/step - loss: 0.4141 - accuracy: 0.8271 - val_loss: 1.5952 - val_accuracy: 0.6333
# Epoch 20/50
# 15/15 [==============================] - 112s 8s/step - loss: 1.0981 - accuracy: 0.7000 - val_loss: 0.2981 - val_accuracy: 0.8750
# Epoch 21/50
# 15/15 [==============================] - 134s 9s/step - loss: 0.4098 - accuracy: 0.8458 - val_loss: 0.8050 - val_accuracy: 0.7583
# Epoch 22/50
# 15/15 [==============================] - 112s 8s/step - loss: 0.3853 - accuracy: 0.8438 - val_loss: 0.2883 - val_accuracy: 0.8833
# Epoch 23/50
# 15/15 [==============================] - 134s 9s/step - loss: 0.3266 - accuracy: 0.8771 - val_loss: 0.3823 - val_accuracy: 0.8583
# Epoch 24/50
# 15/15 [==============================] - 132s 9s/step - loss: 0.2974 - accuracy: 0.8687 - val_loss: 0.3540 - val_accuracy: 0.8583
# Epoch 25/50
# 15/15 [==============================] - 114s 8s/step - loss: 0.4734 - accuracy: 0.8188 - val_loss: 1.5460 - val_accuracy: 0.5667
# Epoch 26/50
# 15/15 [==============================] - 133s 9s/step - loss: 1.2542 - accuracy: 0.7146 - val_loss: 2.4382 - val_accuracy: 0.5583
# Epoch 27/50
# 15/15 [==============================] - 134s 9s/step - loss: 1.6639 - accuracy: 0.6687 - val_loss: 2.3668 - val_accuracy: 0.6500
# Epoch 28/50
# 15/15 [==============================] - 113s 8s/step - loss: 1.4486 - accuracy: 0.7479 - val_loss: 0.7981 - val_accuracy: 0.8750
# Epoch 29/50
# 15/15 [==============================] - 114s 8s/step - loss: 0.6413 - accuracy: 0.8479 - val_loss: 0.5873 - val_accuracy: 0.8750
# Epoch 30/50
# 15/15 [==============================] - 132s 9s/step - loss: 0.7730 - accuracy: 0.8188 - val_loss: 1.8743 - val_accuracy: 0.6667
# Epoch 31/50
# 15/15 [==============================] - 134s 9s/step - loss: 1.4037 - accuracy: 0.7312 - val_loss: 2.1979 - val_accuracy: 0.5750
# Epoch 32/50
# 15/15 [==============================] - 112s 8s/step - loss: 2.4098 - accuracy: 0.6771 - val_loss: 1.0778 - val_accuracy: 0.6917
# Epoch 33/50
# 15/15 [==============================] - 114s 8s/step - loss: 0.8551 - accuracy: 0.8250 - val_loss: 0.3936 - val_accuracy: 0.8917
# Epoch 34/50
# 15/15 [==============================] - 133s 9s/step - loss: 0.4519 - accuracy: 0.8813 - val_loss: 0.4363 - val_accuracy: 0.8750
# Epoch 35/50
# 15/15 [==============================] - 114s 8s/step - loss: 0.4176 - accuracy: 0.8687 - val_loss: 0.3170 - val_accuracy: 0.8833
# Epoch 36/50
# 15/15 [==============================] - 111s 7s/step - loss: 0.3411 - accuracy: 0.8729 - val_loss: 0.6361 - val_accuracy: 0.7417
# Epoch 37/50
# 15/15 [==============================] - 113s 8s/step - loss: 0.5563 - accuracy: 0.8146 - val_loss: 0.7839 - val_accuracy: 0.8000
# Epoch 38/50
# 15/15 [==============================] - 131s 9s/step - loss: 0.3929 - accuracy: 0.8750 - val_loss: 0.4217 - val_accuracy: 0.8750
# Epoch 39/50
# 15/15 [==============================] - 122s 8s/step - loss: 0.4002 - accuracy: 0.8562 - val_loss: 0.5031 - val_accuracy: 0.8500
# Epoch 40/50
# 15/15 [==============================] - 133s 9s/step - loss: 0.3873 - accuracy: 0.8646 - val_loss: 0.2666 - val_accuracy: 0.8917
# Epoch 41/50
# 15/15 [==============================] - 135s 9s/step - loss: 0.2492 - accuracy: 0.8958 - val_loss: 0.2914 - val_accuracy: 0.9083
# Epoch 42/50
# 15/15 [==============================] - 112s 8s/step - loss: 0.3910 - accuracy: 0.8521 - val_loss: 1.0687 - val_accuracy: 0.6667
# Epoch 43/50
# 15/15 [==============================] - 134s 9s/step - loss: 0.3603 - accuracy: 0.8708 - val_loss: 0.6747 - val_accuracy: 0.7500
# Epoch 44/50
# 15/15 [==============================] - 113s 8s/step - loss: 0.4626 - accuracy: 0.8333 - val_loss: 0.4459 - val_accuracy: 0.8667
# Epoch 45/50
# 15/15 [==============================] - 134s 9s/step - loss: 0.3614 - accuracy: 0.8729 - val_loss: 0.6455 - val_accuracy: 0.7583
# Epoch 46/50
# 15/15 [==============================] - 133s 9s/step - loss: 0.3532 - accuracy: 0.8667 - val_loss: 0.2727 - val_accuracy: 0.9000
# Epoch 47/50
# 15/15 [==============================] - 134s 9s/step - loss: 0.5110 - accuracy: 0.8229 - val_loss: 0.3228 - val_accuracy: 0.9083
# Epoch 48/50
# 15/15 [==============================] - ETA: 0s - loss: 0.5071 - accuracy: 0.8375Epoch 49/50
# 15/15 [==============================] - 134s 9s/step - loss: 0.4686 - accuracy: 0.8646 - val_loss: 0.3524 - val_accuracy: 0.8917
# Epoch 50/50
# 15/15 [==============================] - 133s 9s/step - loss: 0.2530 - accuracy: 0.8958 - val_loss: 0.2704 - val_accuracy: 0.9167

# %%
Y_pred = model.predict(X_val)
Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)
cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# 4/4 [==============================] - 41s 7s/step
# Text(0.5, 192.72222222222217, 'Predicted')

# %%
# accuracy plot
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
#path='imbalanced/Scratch/Scratch_400.jpg'
import keras.utils as image
img = image.load_img('/content/drive/MyDrive/Test_cancer/imgtest 1-297.jpg', grayscale=False, target_size=(224, 224))
show_img=image.load_img('/content/drive/MyDrive/Test_cancer/imgtest 1-297.jpg', grayscale=False, target_size=(224, 224))
disease_class=['M','B']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255
custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)

print('Prediction:',disease_class[ind])
# Out:
# 1/1 [==============================] - 1s 1s/step
# [0.1772611 0.8227389 0.       ]
# Prediction: B
